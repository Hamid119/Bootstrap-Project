# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamid119/Bootstrap-Project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-10,10)
plt.plot(x,np.sign(x))
plt.axis('tight')
plt.title('Activation Function : Signum')
plt.show()
